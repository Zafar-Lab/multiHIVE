# %%
# !git clone https://github.com/Zafar-Lab/multiHIVE.git
# Out:
# Cloning into 'multiHIVE'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 49 (delta 9), reused 44 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 18.85 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# install the packages in the same manner
# !pip install scvi-tools==0.20.0
# !pip install scanpy==1.10.0
# !pip install anndata==0.10.6
# !pip install scikit-misc
# Out:
# Collecting scvi-tools==0.20.0
#   Downloading scvi_tools-0.20.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting anndata>=0.7.5 (from scvi-tools==0.20.0)
#   Downloading anndata-0.11.3-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: chex in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (0.1.88)
# Collecting docrep>=0.3.2 (from scvi-tools==0.20.0)
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: flax in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (0.10.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (3.12.1)
# Requirement already satisfied: jax>=0.3 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (0.4.33)
# Collecting ml-collections>=0.1.1 (from scvi-tools==0.20.0)
#   Downloading ml_collections-1.0.0-py3-none-any.whl.metadata (22 kB)
# Collecting mudata>=0.1.2 (from scvi-tools==0.20.0)
#   Downloading mudata-0.3.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (1.26.4)
# Collecting numpyro (from scvi-tools==0.20.0)
#   Downloading numpyro-0.16.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: openpyxl>=3.0 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (3.1.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (0.2.4)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (2.2.2)
# Collecting pyro-ppl>=1.6.0 (from scvi-tools==0.20.0)
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting pytorch-lightning<1.10.0,>=1.9.0 (from scvi-tools==0.20.0)
#   Downloading pytorch_lightning-1.9.5-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (13.9.4)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (2.5.1+cu121)
# Collecting torchmetrics>=0.11.0 (from scvi-tools==0.20.0)
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.11/dist-packages (from scvi-tools==0.20.0) (4.67.1)
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.7.5->scvi-tools==0.20.0)
#   Downloading array_api_compat-1.10.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from anndata>=0.7.5->scvi-tools==0.20.0) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from anndata>=0.7.5->scvi-tools==0.20.0) (24.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from docrep>=0.3.2->scvi-tools==0.20.0) (1.17.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3->scvi-tools==0.20.0) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.3->scvi-tools==0.20.0) (3.4.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from ml-collections>=0.1.1->scvi-tools==0.20.0) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from ml-collections>=0.1.1->scvi-tools==0.20.0) (6.0.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.0->scvi-tools==0.20.0) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0->scvi-tools==0.20.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0->scvi-tools==0.20.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0->scvi-tools==0.20.0) (2025.1)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.6.0->scvi-tools==0.20.0)
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: fsspec>2021.06.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (2024.10.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (4.12.2)
# Collecting lightning-utilities>=0.6.0.post0 (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->scvi-tools==0.20.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->scvi-tools==0.20.0) (2.18.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.2->scvi-tools==0.20.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.2->scvi-tools==0.20.0) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->scvi-tools==0.20.0) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->scvi-tools==0.20.0) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->scvi-tools==0.20.0) (1.3.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex->scvi-tools==0.20.0) (0.12.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax->scvi-tools==0.20.0) (1.1.0)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax->scvi-tools==0.20.0) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax->scvi-tools==0.20.0) (0.1.71)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.11/dist-packages (from numpyro->scvi-tools==0.20.0) (1.0.0)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->scvi-tools==0.20.0) (1.11.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (3.11.11)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.6.0.post0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (75.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->scvi-tools==0.20.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->scvi-tools==0.20.0) (3.0.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->scvi-tools==0.20.0) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->scvi-tools==0.20.0) (4.25.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->scvi-tools==0.20.0) (4.11.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (1.18.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epy]->optax->scvi-tools==0.20.0) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epy]->optax->scvi-tools==0.20.0) (3.21.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools==0.20.0) (3.10)
# Downloading scvi_tools-0.20.0-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.2/330.2 kB 8.1 MB/s eta 0:00:00
# Downloading anndata-0.11.3-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 10.1 MB/s eta 0:00:00
# Downloading ml_collections-1.0.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 5.1 MB/s eta 0:00:00
# Downloading mudata-0.3.1-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 2.8 MB/s eta 0:00:00
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 24.3 MB/s eta 0:00:00
# Downloading pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 37.1 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 34.1 MB/s eta 0:00:00
# Downloading numpyro-0.16.1-py3-none-any.whl (356 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.1/356.1 kB 19.8 MB/s eta 0:00:00
# Downloading array_api_compat-1.10.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Building wheels for collected packages: docrep
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19877 sha256=019640a4802498c02b653e616e4c53180735fbbee8e3684fbaf75ac99401b699
#   Stored in directory: /root/.cache/pip/wheels/06/76/8f/0ecb7d357c0bff71a2bd1940671be2d07a200752da9189bb55
# Successfully built docrep
# Installing collected packages: pyro-api, ml-collections, lightning-utilities, docrep, array-api-compat, anndata, torchmetrics, pyro-ppl, numpyro, mudata, pytorch-lightning, scvi-tools
# Successfully installed anndata-0.11.3 array-api-compat-1.10.0 docrep-0.3.2 lightning-utilities-0.11.9 ml-collections-1.0.0 mudata-0.3.1 numpyro-0.16.1 pyro-api-0.1.2 pyro-ppl-1.9.1 pytorch-lightning-1.9.5 scvi-tools-0.20.0 torchmetrics-1.6.1
# Collecting scanpy==1.10.0
#   Downloading scanpy-1.10.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: anndata>=0.8 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (0.11.3)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (3.12.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (1.4.2)
# Collecting legacy-api-wrap>=1.4 (from scanpy==1.10.0)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (3.4.2)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (0.60.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (24.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (2.2.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (1.0.1)
# Collecting pynndescent>=0.5 (from scanpy==1.10.0)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (1.6.1)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (1.13.1)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (0.13.2)
# Collecting session-info (from scanpy==1.10.0)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (0.14.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from scanpy==1.10.0) (4.67.1)
# Collecting umap-learn!=0.5.0,>=0.5 (from scanpy==1.10.0)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /usr/local/lib/python3.11/dist-packages (from anndata>=0.8->scanpy==1.10.0) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->scanpy==1.10.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->scanpy==1.10.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->scanpy==1.10.0) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->scanpy==1.10.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->scanpy==1.10.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->scanpy==1.10.0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->scanpy==1.10.0) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56->scanpy==1.10.0) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->scanpy==1.10.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5->scanpy==1.10.0) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.24->scanpy==1.10.0) (3.5.0)
# Collecting stdlib_list (from session-info->scanpy==1.10.0)
#   Downloading stdlib_list-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->scanpy==1.10.0) (1.17.0)
# Downloading scanpy-1.10.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.0 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.6 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 5.4 MB/s eta 0:00:00
# Downloading stdlib_list-0.11.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 6.3 MB/s eta 0:00:00
# Building wheels for collected packages: session-info
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8023 sha256=21881f7b5dfb5724eb721022203d742ca38e27bff196cb9c5b0689afea69b0a0
#   Stored in directory: /root/.cache/pip/wheels/4e/56/35/a748fc57279a4b84d0b332879445fed1ad8478e7257986b015
# Successfully built session-info
# Installing collected packages: stdlib_list, legacy-api-wrap, session-info, pynndescent, umap-learn, scanpy
# Successfully installed legacy-api-wrap-1.4.1 pynndescent-0.5.13 scanpy-1.10.0 session-info-1.0.0 stdlib_list-0.11.0 umap-learn-0.5.7
# Collecting anndata==0.10.6
#   Downloading anndata-0.10.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.6) (1.10.0)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.6) (3.12.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.6) (8.4.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.6) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.6) (24.2)
# Requirement already satisfied: pandas!=2.1.0rc0,!=2.1.2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.6) (2.2.2)
# Requirement already satisfied: scipy>1.8 in /usr/local/lib/python3.11/dist-packages (from anndata==0.10.6) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.6) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.6) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.6) (1.17.0)
# Downloading anndata-0.10.6-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.1/122.1 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: anndata
#   Attempting uninstall: anndata
#     Found existing installation: anndata 0.11.3
#     Uninstalling anndata-0.11.3:
#       Successfully uninstalled anndata-0.11.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mudata 0.3.1 requires anndata>=0.10.8, but you have anndata 0.10.6 which is incompatible.
# Successfully installed anndata-0.10.6
# Collecting scikit-misc
#   Downloading scikit_misc-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scikit-misc) (1.26.4)
# Downloading scikit_misc-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.0/189.0 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: scikit-misc
# Successfully installed scikit-misc-0.5.1

# %%
# !pip list | grep scvi  # 0.20.0
# !pip list | grep scanpy # 1.10.0
# !pip list | grep anndata # 0.10.6
# Out:
# scvi-tools                         0.20.0
# scanpy                             1.10.0
# anndata                            0.10.6

# %%
# before import make sure this then import anything else. Else it might raise warnings
# !pip list | grep scvi
# !pip list | grep scanpy
# !pip list | grep anndata
# Out:
# scvi-tools                         0.20.0
# scanpy                             1.10.0
# anndata                            0.10.6

# %%
import scvi
import scanpy as sc
import sys
sys.path.append("/content/multiHIVE")
from src.model import HierarVI
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 0

# %%
adata = scvi.data.pbmcs_10x_cite_seq()
adata
# Out:
# INFO     Downloading file at data/pbmc_10k_protein_v3.h5ad
# Downloading...: 24938it [00:00, 98106.81it/s]
# INFO     Downloading file at data/pbmc_5k_protein_v3.h5ad
# Downloading...: 100%|██████████| 18295/18295.0 [00:00<00:00, 70889.79it/s]
# /usr/local/lib/python3.11/dist-packages/scvi/data/_built_in_data/_cite_seq.py:48: ImplicitModificationWarning: Setting element `.obsm['protein_expression']` of view, initializing view as actual.
#   dataset1.obsm["protein_expression"] = pd.DataFrame(
# /usr/local/lib/python3.11/dist-packages/scvi/data/_built_in_data/_cite_seq.py:53: ImplicitModificationWarning: Setting element `.obsm['protein_expression']` of view, initializing view as actual.
#   dataset2.obsm["protein_expression"] = pd.DataFrame(
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 10849 × 15792
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'batch'
#     obsm: 'protein_expression'

# %%
adata.layers["counts"] = adata.X.copy()
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
adata.raw = adata

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=4000,
    flavor="seurat_v3",
    batch_key="batch",
    subset=True,
    layer="counts"
)

HierarVI.setup_anndata(
    adata,
    layer="counts",
    batch_key="batch",
    protein_expression_obsm_key="protein_expression"
)
# Out:
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /usr/local/lib/python3.11/dist-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# <frozen abc>:119: FutureWarning: SparseDataset is deprecated and will be removed in late 2024. It has been replaced by the public classes CSRDataset and CSCDataset.
#
# For instance checks, use `isinstance(X, (anndata.experimental.CSRDataset, anndata.experimental.CSCDataset))` instead.
#
# For creation, use `anndata.experimental.sparse_dataset(X)` instead.
# INFO     Using column names from columns of adata.obsm['protein_expression']
# <frozen abc>:119: FutureWarning: SparseDataset is deprecated and will be removed in late 2024. It has been replaced by the public classes CSRDataset and CSCDataset.
#
# For instance checks, use `isinstance(X, (anndata.experimental.CSRDataset, anndata.experimental.CSCDataset))` instead.
#
# For creation, use `anndata.experimental.sparse_dataset(X)` instead.

# %%
import numpy as np
import matplotlib.pyplot as plt

vae = HierarVI(adata)
vae.train(max_epochs=200)
adata.obsm["Zs1"], adata.obsm["Zs2"], adata.obsm["Zr"], adata.obsm["Zp"] = vae.get_latent_representation()
adata.obsm['Z_multiHIVE'] = np.concatenate((adata.obsm["Zs1"], adata.obsm["Zr"], adata.obsm["Zp"]), axis=1)

#generated_data = vae.posterior_predictive_sample(adata, swap_latent=False)

plt.plot(vae.history["elbo_train"], label="train")
plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
plt.legend()
# Out:
# INFO     Computing empirical prior initialization for protein background.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/core/optimizer.py:331: RuntimeWarning: The lr scheduler dict contains the key(s) ['monitor'], but the keys will be ignored. You need to call `lr_scheduler.step()` manually in manual optimization.
#   rank_zero_warn(
# Epoch 200/200: 100%|██████████| 200/200 [47:37<00:00, 14.22s/it, v_num=1]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 200/200: 100%|██████████| 200/200 [47:37<00:00, 14.29s/it, v_num=1]

# %%
sc.pp.neighbors(adata, use_rep = "Z_multiHIVE")
sc.tl.umap(adata)
sc.pl.umap(adata, color = "batch")
